# %%
import warnings
warnings.filterwarnings('ignore',category=RuntimeWarning)
import xarray as xr
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import glob,os
from tqdm import tqdm
import datetime
import proplot as plot
from netCDF4 import Dataset
from wrf import getvar
# %matplotlib inline

plot.rc.update({'figure.facecolor':'w','axes.labelweight':'ultralight',
                'tick.labelweight':'ultralight','gridminor.linestyle':'--','title.weight':'normal','linewidth':0.5})

# %% [markdown]
# Read in stuff

# %%
import pickle
path = './output/1010_ns/'
#filePCA = [path+'dtheta_pca',path+'du_pca',path+'dv_pca',path+'u_pca',path+'v_pca']
#fileA = [path+'normalT_ctrl',path+'normalDU_ctrl',path+'normalDV_ctrl',path+'normalU_ctrl',path+'normalV_ctrl']
#fileAf = [path+'normalT_ctrlf',path+'normalDU_ctrlf',path+'normalDV_ctrlf',path+'normalU_ctrlf',path+'normalV_ctrlf']
filePCA = [path+'dtheta_pca_ns',path+'du_pca_ns',path+'dv_pca_ns',path+'u_pca_ns',path+'v_pca_ns']
fileA = [path+'normalT_ctrl_ns',path+'normalDU_ctrl_ns',path+'normalDV_ctrl_ns',path+'normalU_ctrl_ns',path+'normalV_ctrl_ns']
fileAf = [path+'normalT_ctrlf_ns',path+'normalDU_ctrlf_ns',path+'normalDV_ctrlf_ns',path+'normalU_ctrlf_ns',path+'normalV_ctrlf_ns']

outputPCA,outputA,outputAf = [],[],[]
for i in range(len(filePCA)):
    with open(filePCA[i],'rb') as f:
        outputPCA.append(pickle.load(f))
    with open(fileA[i],'rb') as f:
        outputA.append(pickle.load(f))
    with open(fileAf[i],'rb') as f:
        outputAf.append(pickle.load(f))

PCA_dict = {'dtheta':outputPCA[0],'du':outputPCA[1],'dv':outputPCA[2],'u':outputPCA[3],'v':outputPCA[4]}
A_dict = {'dtheta':outputA[0],'du':outputA[1],'dv':outputA[2],'u':outputA[3],'v':outputA[4]}
Af_dict = {'dtheta':outputAf[0],'du':outputAf[1],'dv':outputAf[2],'u':outputAf[3],'v':outputAf[4]}

# %% [markdown]
# #### We first plot the explained variance ratio

# %%
import matplotlib.patheffects as path_effects
import matplotlib as mpl
cmap = mpl.cm.get_cmap('tab10')
cmapC = cmap((np.linspace(0.15,0.8,5)))
fig,axs = plot.subplots(ncols=1,nrows=1,axwidth=2.75,refaspect=2.051,span=False)
with sns.color_palette("Spectral", n_colors=5):
    axs[0].plot(np.linspace(0,PCA_dict['dtheta'].explained_variance_ratio_.cumsum().shape[0]-1,\
                            PCA_dict['dtheta'].explained_variance_ratio_.cumsum().shape[0]),\
                PCA_dict['dtheta'].explained_variance_ratio_.cumsum(),lw=2,label='dT/dt',color=cmapC[0])
    axs[0].plot(np.linspace(0,PCA_dict['du'].explained_variance_ratio_.cumsum().shape[0]-1,\
                            PCA_dict['du'].explained_variance_ratio_.cumsum().shape[0]),\
                PCA_dict['du'].explained_variance_ratio_.cumsum(),lw=2,label='dU',color=cmapC[1])
    axs[0].plot(np.linspace(0,PCA_dict['dv'].explained_variance_ratio_.cumsum().shape[0]-1,\
                            PCA_dict['dv'].explained_variance_ratio_.cumsum().shape[0]),\
                PCA_dict['dv'].explained_variance_ratio_.cumsum(),lw=2,label='dV',color=cmapC[2])
    axs[0].plot(np.linspace(0,PCA_dict['u'].explained_variance_ratio_.cumsum().shape[0]-1,\
                            PCA_dict['u'].explained_variance_ratio_.cumsum().shape[0]),\
                PCA_dict['u'].explained_variance_ratio_.cumsum(),lw=2,label='U',color=cmapC[3])
    axs[0].plot(np.linspace(0,PCA_dict['v'].explained_variance_ratio_.cumsum().shape[0]-1,\
                            PCA_dict['v'].explained_variance_ratio_.cumsum().shape[0]),\
                PCA_dict['v'].explained_variance_ratio_.cumsum(),lw=2,label='V',color=cmapC[4],
                path_effects=[path_effects.Stroke(linewidth=1,foreground='k'),path_effects.Normal()])
axs[0].format(xlabel='PCA component',ylabel='Cumul. Exp. Var. Ratio')
axs[0].legend(loc='lr')
axs.format(xlim=[0,25],ltitle='Day1-Day4.5',rtitle='Maria')
for axis in axs:
    axis.yaxis.label.set_size(8.5)
    axis.xaxis.label.set_size(8.5)
    axis.tick_params(axis='both', which='major', labelsize=8)
plt.show()

# %% [markdown]
# Smoother fields require less PCA components to explain 80\% variance than difference terms.

# %%
from scipy.ndimage import uniform_filter1d
# PCA time series (scaled to unit variance)
#################################################
pca_timeseries = PCA_dict['dtheta'].transform(Af_dict['dtheta'])[:,0:6]/np.sqrt(PCA_dict['dtheta'].explained_variance_[0:6])
pcadu_timeseries = PCA_dict['du'].transform(Af_dict['du'])[:,0:6]/np.sqrt(PCA_dict['du'].explained_variance_[0:6])
pcadv_timeseries = PCA_dict['dv'].transform(Af_dict['dv'])[:,0:6]/np.sqrt(PCA_dict['dv'].explained_variance_[0:6])

#Plot
#############################################################################################################
fig,axs = plot.subplots(ncols=3,nrows=1,axwidth=3.25,refaspect=2.051,span=False)
axs[0].plot(np.linspace(0,83,84)/24,uniform_filter1d(pca_timeseries[:,0],1),c='k',label='PCA01')
axs[0].plot(np.linspace(0,83,84)/24,uniform_filter1d(pca_timeseries[:,1],1),c='r',label='PCA02')
axs[0].plot(np.linspace(0,83,84)/24,uniform_filter1d(pca_timeseries[:,2],1),c='b',label='PCA03')
axs[0].plot(np.linspace(0,83,84)/24,uniform_filter1d(pca_timeseries[:,3],1),c='g',label='PCA04')
axs[0].plot(np.linspace(0,83,84)/24,uniform_filter1d(pca_timeseries[:,4],1),c='m',label='PCA05')
axs[0].format(xlim=[0,3.5],xlabel='Days after Day 1',ylabel='PCA/max(PCA)')#ylim=[-10,25],
axs[0].legend(loc='ur',ncols=2,prop={'size':6})
axs[0].format(ltitle=r'd$\theta$/dt, Day1-Day4.5',rtitle='Maria')

axs[1].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcadu_timeseries[:,0],1),c='k',label='PCA01')
axs[1].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcadu_timeseries[:,1],1),c='r',label='PCA02')
axs[1].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcadu_timeseries[:,2],1),c='b',label='PCA03')
axs[1].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcadu_timeseries[:,3],1),c='g',label='PCA04')
axs[1].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcadu_timeseries[:,4],1),c='m',label='PCA05')
axs[1].format(xlim=[0,3.5],xlabel='Days after Day 1',ylabel='PCA/max(PCA)')#ylim=[-10,25],
axs[1].legend(loc='ur',ncols=2,prop={'size':6})
axs[1].format(ltitle=r'd$u$/dt, Day1-Day4.5',rtitle='Maria')

axs[2].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcadv_timeseries[:,0],1),c='k',label='PCA01')
axs[2].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcadv_timeseries[:,1],1),c='r',label='PCA02')
axs[2].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcadv_timeseries[:,2],1),c='b',label='PCA03')
axs[2].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcadv_timeseries[:,3],1),c='g',label='PCA04')
axs[2].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcadv_timeseries[:,4],1),c='m',label='PCA05')
axs[2].format(xlim=[0,3.5],xlabel='Days after Day 1',ylabel='PCA')#ylim=[-10,25],
axs[2].legend(loc='ur',ncols=2,prop={'size':6})
axs[2].format(ltitle=r'd$v$/dt, Day1-Day4.5',rtitle='Maria')
for axis in axs:
    axis.yaxis.label.set_size(8.5)
    axis.xaxis.label.set_size(8.5)
    axis.tick_params(axis='both', which='major', labelsize=8)
plt.show()

# %%
pcau_timeseries = PCA_dict['u'].transform(Af_dict['u'])[:,0:6]/np.sqrt(PCA_dict['u'].explained_variance_[0:6])
pcav_timeseries = PCA_dict['v'].transform(Af_dict['v'])[:,0:6]/np.sqrt(PCA_dict['v'].explained_variance_[0:6])

#Plot
#############################################################################################################
fig,axs = plot.subplots(ncols=2,nrows=1,axwidth=3.25,refaspect=2.051,span=False)
axs[0].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcau_timeseries[:,0],1),c='k',label='PCA01')
axs[0].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcau_timeseries[:,1],1),c='r',label='PCA02')
axs[0].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcau_timeseries[:,2],1),c='b',label='PCA03')
axs[0].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcau_timeseries[:,3],1),c='g',label='PCA04')
axs[0].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcau_timeseries[:,4],1),c='m',label='PCA05')
axs[0].format(xlim=[0,3.5],xlabel='Days after Day 1',ylabel='PCA/max(PCA)')#ylim=[-10,25],
axs[0].legend(loc='ur',ncols=2,prop={'size':6})
axs[0].format(ltitle=r'u, Day1-Day4.5',rtitle='Maria')

axs[1].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcav_timeseries[:,0],1),c='k',label='PCA01')
axs[1].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcav_timeseries[:,1],1),c='r',label='PCA02')
axs[1].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcav_timeseries[:,2],1),c='b',label='PCA03')
axs[1].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcav_timeseries[:,3],1),c='g',label='PCA04')
axs[1].plot(np.linspace(0,83,84)/24,uniform_filter1d(pcav_timeseries[:,4],1),c='m',label='PCA05')
axs[1].format(xlim=[0,3.5],xlabel='Days after Day 1',ylabel='PCA/max(PCA)')#ylim=[-10,25],
axs[1].legend(loc='ur',ncols=2,prop={'size':6})
axs[1].format(ltitle=r'v, Day1-Day4.5',rtitle='Maria')

for axis in axs:
    axis.yaxis.label.set_size(8.5)
    axis.xaxis.label.set_size(8.5)
    axis.tick_params(axis='both', which='major', labelsize=8)
plt.show()

# %% [markdown]
# #### Correlation plot

# %%
origin_path = '/scratch/06040/tg853394/tc/output/redux/maria/'
#Function####################################################
import json,pickle
def read_some_azimuth_fields(fileloc=None,fieldname=None):
    dict_name = {}
    for inx,obj in enumerate(fileloc):
        field_read = xr.open_dataset(obj)
        dict_name[fieldname[inx]] = field_read
    return dict_name
def nearest_index(array, value):
    idx = (np.abs(array-value)).argmin()
    return idx.values
def save_to_pickle(loc=None,var=None):
    with open(loc,"wb") as f:
        pickle.dump(var,f)
    return None
#############################################################
#########################################################################################################
ctrlvar_dict = read_some_azimuth_fields(fileloc=[origin_path+'ctl/azim_U10_0-144hr.nc',
                                                 origin_path+'ctl/azim_QVAPOR_0-144hr.nc',
                                                 origin_path+'ctl/azim_RTHRATLW_0-144hr.nc',
                                                 origin_path+'ctl/azim_RTHRATLWC_0-144hr.nc',
                                                 origin_path+'ctl/azim_RTHRATSW_0-144hr.nc',
                                                 origin_path+'ctl/azim_RTHRATSWC_0-144hr.nc',
                                                 origin_path+'ctl/azim_H_DIABATIC_0-144hr.nc',
                                                origin_path+'ctl/azim_LH_0-144hr.nc'],
                                        fieldname=['U10','QVAPOR','RTHRATLW','RTHRATLWC','RTHRATSW','RTHRATSWC',
                                                  'H_DIABATIC','LH'])
r0,r200=(nearest_index(ctrlvar_dict['U10']['U10'].radius,0),nearest_index(ctrlvar_dict['U10']['U10'].radius,200))
r300,r500=(nearest_index(ctrlvar_dict['U10']['U10'].radius,300),nearest_index(ctrlvar_dict['U10']['U10'].radius,500))

# %%
def export_corrmap(PCAinput=None,orig_normalarray=None,orig_flatarray=None,component=4,TYPE='correlation'):
    # Adapted from eofs package
    slicer = slice(0,component)
    dt_eigenvector = PCAinput.components_[:,slicer].copy()/np.sqrt(PCAinput.explained_variance_[slicer])
    dt_eigenvector_a = dt_eigenvector-np.nanmean(dt_eigenvector,axis=0)
    ############################################
    # Center pcs and field
    ############################################
    pcs_std = np.nanstd(dt_eigenvector_a,axis=0)
    field_std = np.nanstd(orig_flatarray,axis=0)
    ############################################
    # Set the divisor.
    ############################################
    div = np.float64(dt_eigenvector_a.shape[0])
    ############################################
    # Compute the correlation map.
    ############################################
    cor = np.ma.dot(orig_flatarray.T, dt_eigenvector_a).T / div
    if TYPE=='correlation':
        cor = np.ma.masked_invalid(cor)
        cor /= np.ma.outer(pcs_std, field_std)
    else:
        cor=cor
    
    output = []
    for cornum in cor:
        output.append(cornum.reshape(orig_normalarray[0,:,:,:].shape))
    return output

# %%
du_corrmap = export_corrmap(PCA_dict['du'],A_dict['du'],Af_dict['du'],6,'covariance')
dv_corrmap = export_corrmap(PCA_dict['dv'],A_dict['dv'],Af_dict['dv'],6,'covariance')
dt_corrmap = export_corrmap(PCA_dict['dtheta'],A_dict['dtheta'],Af_dict['dtheta'],6,'covariance')

path_coor = '/scratch/06040/tg853394/tc/output/redux/maria/ctl/post/U.nc'
coor = xr.open_dataset(path_coor)

# %%
[np.abs(coor.pres-obj).argmin() for obj in [1000,850,500,200,150]]
# Out:
# [<xarray.DataArray 'pres' ()>
#  array(0),
#  <xarray.DataArray 'pres' ()>
#  array(6),
#  <xarray.DataArray 'pres' ()>
#  array(20),
#  <xarray.DataArray 'pres' ()>
#  array(32),
#  <xarray.DataArray 'pres' ()>
#  array(34)]

# %%
import matplotlib.ticker as mticker
#heightindx = 34
for heightindx in tqdm([0,6,20,32,34]):#range(len(coor.pres.data))):
    fig,axs = plot.subplots(ncols=3,nrows=2,axwidth=2.85,refaspect=1.251,span=False)
    img=axs[0].contourf(ctrlvar_dict['U10'].radius[:r500],ctrlvar_dict['U10'].azmiuth,dv_corrmap[0][heightindx]*3600,
                        levels=np.linspace(-0.08,0.08,65),cmap='BuRd',extend='both')
    axs[0].colorbar(img,loc='lr',ticks=[-0.06,0,0.06])
    axs[0].format(xlim=[0,500],ylim=[0,360],xlabel='Distance from TC centre (km)',ltitle='Day 1-Day 4.5',
                  rtitle=r'PCA01 ({} hPa)'.format(int(coor.pres[heightindx].data)))
    img=axs[1].contourf(ctrlvar_dict['U10'].radius[:r500],ctrlvar_dict['U10'].azmiuth,dv_corrmap[1][heightindx]*3600,
                        levels=np.linspace(-0.08,0.08,65),cmap='BuRd',extend='both')
    axs[1].colorbar(img,loc='lr',ticks=[-0.06,0,0.06])
    axs[1].format(xlim=[0,500],ylim=[0,360],xlabel='Distance from TC centre (km)',
                  title=r'PCA02 ({} hPa)'.format(int(coor.pres[heightindx].data)))
    img=axs[2].contourf(ctrlvar_dict['U10'].radius[:r500],ctrlvar_dict['U10'].azmiuth,dv_corrmap[2][heightindx]*3600,
                        levels=np.linspace(-0.08,0.08,65),cmap='BuRd',extend='both')
    axs[2].colorbar(img,loc='lr',ticks=[-0.06,0,0.06])
    axs[2].format(xlim=[0,500],ylim=[0,360],xlabel='Distance from TC centre (km)',
                  title=r'PCA03 ({} hPa)'.format(int(coor.pres[heightindx].data)))
    img=axs[3].contourf(ctrlvar_dict['U10'].radius[:r500],ctrlvar_dict['U10'].azmiuth,dv_corrmap[3][heightindx]*3600,
                        levels=np.linspace(-0.08,0.08,65),cmap='BuRd',extend='both')
    axs[3].colorbar(img,loc='lr',ticks=[-0.06,0,0.06])
    axs[3].format(xlim=[0,500],ylim=[0,360],xlabel='Distance from TC centre (km)',
                  title=r'PCA04 ({} hPa)'.format(int(coor.pres[heightindx].data)))
    img=axs[4].contourf(ctrlvar_dict['U10'].radius[:r500],ctrlvar_dict['U10'].azmiuth,dv_corrmap[4][heightindx]*3600,
                        levels=np.linspace(-0.08,0.08,65),cmap='BuRd',extend='both')
    axs[4].colorbar(img,loc='lr',ticks=[-0.06,0,0.06])
    axs[4].format(xlim=[0,500],ylim=[0,360],xlabel='Distance from TC centre (km)',
                  title=r'PCA05 ({} hPa)'.format(int(coor.pres[heightindx].data)))
    axs.format(yticks=[18.22,108.22,198.22,288.22],yticklabels=['DL','DR','UR','UL'],suptitle='dv/dt',ylabel='')
    for axisobj in axs:
        axisobj.yaxis.set_minor_locator(mticker.AutoMinorLocator(2))
        axisobj.yaxis.label.set_size(8.5)
        axisobj.xaxis.label.set_size(8.5)
        axisobj.tick_params(axis='both', which='major', labelsize=8)
    #plt.savefig('./proc_fig/dvdtPCA'+str(int(coor.pres[heightindx].data))+'_ns.png',dpi=200)
    plt.close()
#plt.show()
# Out:
#  20%|██████████████████████████████████▌                                                                                                                                          | 1/5 [00:11<00:45, 11.41s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_34558/4231996611.py in <module>
#       2 #heightindx = 34
#       3 for heightindx in tqdm([0,6,20,32,34]):#range(len(coor.pres.data))):
# ----> 4     fig,axs = plot.subplots(ncols=3,nrows=2,axwidth=2.85,refaspect=1.251,span=False)
#       5     img=axs[0].contourf(ctrlvar_dict['U10'].radius[:r500],ctrlvar_dict['U10'].azmiuth,dv_corrmap[0][heightindx]*3600,
#       6                         levels=np.linspace(-0.08,0.08,65),cmap='BuRd',extend='both')
#
# ...

# %% [markdown]
# #### To Cartesian

# %%
import scipy
def azimuth2angle(azimuth=None):
    """
    https://math.stackexchange.com/questions/926226/conversion-from-azimuth-to-counterclockwise-angle
    """
    angletest = 450-azimuth
    for index,item in enumerate(angletest):
        if item>360:
            angletest[index] = item-360
        else:
            continue
    return angletest

def closest_index(array=None,target=None):
    return np.abs(array-target).argmin()

def polar2cartesian(outcoords, inputshape, origin):
    """Coordinate transform for converting a polar array to Cartesian coordinates. 
    inputshape is a tuple containing the shape of the polar array. origin is a
    tuple containing the x and y indices of where the origin should be in the
    output array."""

    xindex, yindex = outcoords
    x0, y0 = origin
    x = xindex - x0
    y = yindex - y0

    r = np.sqrt(x**2 + y**2)
    theta = np.arctan2(y, x)
    theta_index = np.round((theta + np.pi) * inputshape[1] / (2 * np.pi))

    return (r,theta_index)

def proc_tocart(polarfield=None,angle=None,twoD=True,twoDlv=None):
    if twoD==True:
        PWnew = [np.asarray(polarfield)[int(twoDlv),int(np.abs(ANGLE-360).argmin()),:]]
        for i in np.linspace(0,358,359):
            PWnew.append(np.asarray(polarfield)[int(twoDlv),int(np.abs(ANGLE-i).argmin()),:])
        PWnew = np.swapaxes(np.asarray(PWnew),0,1)
        del i

        test_2cartesian = scipy.ndimage.geometric_transform(PWnew, 
                                                            polar2cartesian,order=0,mode='constant',
                                                            output_shape = \
                                                            (PWnew.shape[0] * 2,PWnew.shape[0] * 2),
                                                            extra_keywords = \
                                                            {'inputshape':PWnew.shape,
                                                             'origin':(PWnew.shape[0],PWnew.shape[0])})
        #print('Finish processing')
        return ((test_2cartesian))

# %%
ANGLE = azimuth2angle(np.linspace(0,359,360))
NEWCART_axis = np.concatenate((np.flipud(-ctrlvar_dict['U10'].radius[:r500]),ctrlvar_dict['U10'].radius[:r500][:]))

# %%
import matplotlib.ticker as mticker
#heightindx = 34
pcano=0
maptoplot = dv_corrmap.copy()
for heightindx in tqdm([0,6,20,32,34]):
    fig,axs = plot.subplots(ncols=2,nrows=1,axwidth=2.85,refaspect=1.251,span=False,sharey=False)
    img = axs[0].contourf(ctrlvar_dict['U10'].radius[:r500],ctrlvar_dict['U10'].azmiuth,
                          maptoplot[pcano][heightindx]*3600,
                          levels=np.linspace(-0.1,0.1,41),cmap='BuRd',extend='both')
    axs[0].colorbar(img,loc='lr',ticks=[-0.08,0,0.08])
    axs[0].format(xlim=[0,500],ylim=[0,360],xlabel='Distance from TC centre (km)',ltitle='Day 1-Day 4.5',
                  rtitle=r'PCA0'+str(pcano+1)+'({} hPa)'.format(int(coor.pres[heightindx].data)))
    axs[1].contourf(NEWCART_axis,NEWCART_axis,
                    np.fliplr(np.flipud((proc_tocart(maptoplot[pcano],ANGLE,True,heightindx)*3600).transpose())),
                    levels=np.linspace(-0.1,0.1,41),
                    cmap='BuRd',extend='both') #-.08,.08,33 (dt) -.1,.1,41 (du/dv)
    axs[1].format(xlabel='X (km)',ylabel='Y (km)',ltitle='Cartesian',
                  rtitle=r'PCA0'+str(pcano+1)+'({} hPa)'.format(int(coor.pres[heightindx].data)))
    plt.savefig('./proc_fig/dvdtPCA0'+str(pcano+1)+'_'+str(int(coor.pres[heightindx].data))+'_nsCART.png',dpi=200)
    plt.close()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 5/5 [02:01<00:00, 24.40s/it]

# %%
plt.contourf(NEWCART_axis,NEWCART_axis,
                    np.fliplr(np.flipud(A.transpose())),
                    levels=np.linspace(-0.1,0.1,41),
                    cmap='BuRd',extend='both')
plt.show()

# %% [markdown]
# #### Project other terms onto PCA

# %%
def preproc_fields(var=None,timezoom=None,smooth='Yes',gaussian=0.9,fromcenter='Yes',inradius=None,outradius=r500,dostandard='Yes'):
    """
    Var: Input variable (must have 4 dimensions! Time-pres-theta-radius)
    """
    if smooth=='Yes':
        from scipy.ndimage import gaussian_filter
        normal_var = []
        if dostandard=='Yes':
            for presindex in range(len(var[0,:,0,0])):
                normal_var.append(gaussian_filter(normalize_inner(var[:,presindex,:,:],outradius,'Yes'),sigma=gaussian))
        elif dostandard=='No':
            for presindex in range(len(var[0,:,0,0])):
                normal_var.append(gaussian_filter(normalize_inner(var[:,presindex,:,:],outradius,'No'),sigma=gaussian))            
        normal_var = np.swapaxes(np.asarray(normal_var),0,1)
    else:
        normal_var = []
        for presindex in range(len(var[0,:,0,0])):
            normal_var.append(normalize_inner(var[:,presindex,:,:],outradius))
        normal_var = np.swapaxes(np.asarray(normal_var),0,1)
    if fromcenter=='Yes':
        normal_varf = np.asarray([normal_var[i,:,:,:outradius].flatten() \
                                  for i in range(len(normal_var[timezoom[0]:timezoom[1],0,0,0]))])
    elif fromcenter=='No':
        normal_varf = np.asarray([normal_var[i,:,:,inradius:outradius].flatten() \
                                  for i in range(len(normal_var[timezoom[0]:timezoom[1],0,0,0]))])        
    print("--Finish preprocesing--")
    return normal_var,normal_varf

def normalize_inner(var=None,outerradius=None,standard='Yes'):
    PWper_ctrl = []
    for indx in range(len(var[:,0,0])):
        temp = var[indx,:,:outerradius]-np.nanmean(var[indx,:,:outerradius],axis=(0,1))
        if standard=='Yes':
            PWper_ctrl.append((temp-np.nanmean(temp))/np.nanstd(temp))
        elif standard=='No':
            PWper_ctrl.append((temp))
    del temp
    return np.asarray(PWper_ctrl)

class MidpointNormalize(mpl.colors.Normalize):
    def __init__(self, vmin, vmax, midpoint=0, clip=False):
        self.midpoint = midpoint
        mpl.colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        normalized_min = max(0, 1 / 2 * (1 - abs((self.midpoint - self.vmin) / (self.midpoint - self.vmax))))
        normalized_max = min(1, 1 / 2 * (1 + abs((self.vmax - self.midpoint) / (self.midpoint - self.vmin))))
        normalized_mid = 0.5
        x, y = [self.vmin, self.midpoint, self.vmax], [normalized_min, normalized_mid, normalized_max]
        return np.ma.masked_array(np.interp(value, x, y))

# %%
RTHRAT_CLW = ctrlvar_dict['RTHRATLW']['RTHRATLW']-ctrlvar_dict['RTHRATLWC']['RTHRATLWC']
RTHRAT_CSW = ctrlvar_dict['RTHRATSW']['RTHRATSW']-ctrlvar_dict['RTHRATSWC']['RTHRATSWC']

# %%
###################################################################
# Cut off time
###################################################################
ctrl_t2,ctrl_t4 = nearest_index(ctrlvar_dict['QVAPOR']['QVAPOR'].time/24,1)-1,nearest_index(ctrlvar_dict['QVAPOR']['QVAPOR'].time/24,4.5)-1

normalQVctrl,normalQVctrlf = preproc_fields(var=ctrlvar_dict['QVAPOR']['QVAPOR'],timezoom=[ctrl_t2,ctrl_t4],smooth='Yes',
                                  gaussian=[3,0,0],fromcenter='Yes',inradius=None,outradius=r500,dostandard='No')
qv_corrmap = export_corrmap(PCA_dict['dtheta'],normalQVctrl,normalQVctrlf,6,'covariance')

normalRTHRATLWctrl,normalRTHRATLWctrlf = preproc_fields(var=ctrlvar_dict['RTHRATLW']['RTHRATLW'],timezoom=[ctrl_t2,ctrl_t4],smooth='Yes',
                                  gaussian=[3,0,0],fromcenter='Yes',inradius=None,outradius=r500,dostandard='No')
RTHRATLW_corrmap = export_corrmap(PCA_dict['dtheta'],normalRTHRATLWctrl,normalRTHRATLWctrlf,6,'covariance')

normalRTHRATLWCctrl,normalRTHRATLWCctrlf = preproc_fields(var=ctrlvar_dict['RTHRATLWC']['RTHRATLWC'],timezoom=[ctrl_t2,ctrl_t4],smooth='Yes',
                                  gaussian=[3,0,0],fromcenter='Yes',inradius=None,outradius=r500,dostandard='No')
RTHRATLWC_corrmap = export_corrmap(PCA_dict['dtheta'],normalRTHRATLWCctrl,normalRTHRATLWCctrlf,6,'covariance')

normalCLWctrl,normalCLWctrlf = preproc_fields(var=RTHRAT_CLW,timezoom=[ctrl_t2,ctrl_t4],smooth='Yes',
                                  gaussian=[3,0,0],fromcenter='Yes',inradius=None,outradius=r500,dostandard='No')
CLW_corrmap = export_corrmap(PCA_dict['dtheta'],normalCLWctrl,normalCLWctrlf,6,'covariance')

# %%
import matplotlib.ticker as mticker
#heightindx = 34
for heightindx in tqdm([0,6,20,32,34]):#,20,32,34]):#range(len(coor.pres.data))):
    fig,axs = plot.subplots(ncols=3,nrows=2,axwidth=2.85,refaspect=1.251,span=False)
    norm = MidpointNormalize(vmin=(qv_corrmap[0][heightindx]*1000).min(),vmax=(qv_corrmap[0][heightindx]*1000).max(), midpoint=0)
    img=axs[0].contourf(ctrlvar_dict['U10'].radius[:r500],ctrlvar_dict['U10'].azmiuth,HDIA_corrmap[0][heightindx]*3600,
                                           cmap='BuRd',extend='both',levels=np.linspace(-0.08,0.08,65))#norm=norm)
    axs[0].colorbar(img,loc='lr',ticks=[-0.06,0,0.06])
    axs[0].format(xlim=[0,500],ylim=[0,360],xlabel='Distance from TC centre (km)',ltitle='Day 1-Day 4.5',
                  rtitle=r'PCA01 ({} hPa)'.format(int(coor.pres[heightindx].data)))
    img=axs[1].contourf(ctrlvar_dict['U10'].radius[:r500],ctrlvar_dict['U10'].azmiuth,HDIA_corrmap[1][heightindx]*3600,
                        cmap='BuRd',extend='both',levels=np.linspace(-0.08,0.08,65))
                        #norm=MidpointNormalize(vmin=(qv_corrmap[1][heightindx]*1000).min(),vmax=(qv_corrmap[1][heightindx]*1000).max(), midpoint=0))
    axs[1].colorbar(img,loc='lr',ticks=[-0.06,0,0.06])
    axs[1].format(xlim=[0,500],ylim=[0,360],xlabel='Distance from TC centre (km)',
                  title=r'PCA02 ({} hPa)'.format(int(coor.pres[heightindx].data)))
    img=axs[2].contourf(ctrlvar_dict['U10'].radius[:r500],ctrlvar_dict['U10'].azmiuth,HDIA_corrmap[2][heightindx]*3600,
                        cmap='BuRd',extend='both',levels=np.linspace(-0.08,0.08,65))
                       #norm=MidpointNormalize(vmin=(qv_corrmap[2][heightindx]*1000).min(),vmax=(qv_corrmap[2][heightindx]*1000).max(), midpoint=0))
    axs[2].colorbar(img,loc='lr',ticks=[-0.06,0,0.06])
    axs[2].format(xlim=[0,500],ylim=[0,360],xlabel='Distance from TC centre (km)',
                  title=r'PCA03 ({} hPa)'.format(int(coor.pres[heightindx].data)))
    img=axs[3].contourf(ctrlvar_dict['U10'].radius[:r500],ctrlvar_dict['U10'].azmiuth,HDIA_corrmap[3][heightindx]*3600,
                        cmap='BuRd',extend='both',levels=np.linspace(-0.08,0.08,65))
                       #norm=MidpointNormalize(vmin=(qv_corrmap[3][heightindx]*1000).min(),vmax=(qv_corrmap[3][heightindx]*1000).max(), midpoint=0))
    axs[3].colorbar(img,loc='lr',ticks=[-0.06,0,0.06])
    axs[3].format(xlim=[0,500],ylim=[0,360],xlabel='Distance from TC centre (km)',
                  title=r'PCA04 ({} hPa)'.format(int(coor.pres[heightindx].data)))
    img=axs[4].contourf(ctrlvar_dict['U10'].radius[:r500],ctrlvar_dict['U10'].azmiuth,HDIA_corrmap[4][heightindx]*3600,
                        cmap='BuRd',extend='both',levels=np.linspace(-0.08,0.08,65))
                       #norm=MidpointNormalize(vmin=(qv_corrmap[4][heightindx]*1000).min(),vmax=(qv_corrmap[4][heightindx]*1000).max(), midpoint=0))
    axs[4].colorbar(img,loc='lr',ticks=[-0.06,0,0.06])
    axs[4].format(xlim=[0,500],ylim=[0,360],xlabel='Distance from TC centre (km)',
                  title=r'PCA05 ({} hPa)'.format(int(coor.pres[heightindx].data)))
    axs.format(yticks=[18.22,108.22,198.22,288.22],yticklabels=['DL','DR','UR','UL'],
               suptitle=r'HDIA-d$\theta$dt PCA',ylabel='')
    for axisobj in axs:
        axisobj.yaxis.set_minor_locator(mticker.AutoMinorLocator(2))
        axisobj.yaxis.label.set_size(8.5)
        axisobj.xaxis.label.set_size(8.5)
        axisobj.tick_params(axis='both', which='major', labelsize=8)
    #plt.savefig('./proc_fig/clw_on_dthPCA'+str(int(coor.pres[heightindx].data))+'_ns.png',dpi=200)
    plt.show()
    #plt.close()
#plt.show()
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [02:54<00:00, 87.40s/it]
