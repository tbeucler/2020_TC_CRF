# %%
import warnings
warnings.filterwarnings('ignore',category=RuntimeWarning)
import xarray as xr
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import glob,os,sys
from tqdm import tqdm
import proplot as plot
import json,pickle
import dask.array as da
import gc
from sklearn.decomposition import PCA
sys.path.insert(1, '/work/FAC/FGSE/IDYST/tbeucler/default/freddy0218/TCGphy/2020_TC_CRF/dev/freddy0218/')
from tools import derive_var,read_and_proc,preproc_noensemble
from tools.mlr import mlr,proc_mlrfcst,maria_IO
from tools.preprocess import do_eof,preproc_maria
#import feature_select
import pysnooper
from dask.distributed import Client
client = Client(processes=True, threads_per_worker=1,n_workers=2)
# %matplotlib inline
plot.rc.update({'figure.facecolor':'w','axes.labelweight':'ultralight',
                'tick.labelweight':'ultralight','gridminor.linestyle':'--','title.weight':'normal','linewidth':0.5})
# Out:
# /work/FAC/FGSE/IDYST/tbeucler/default/freddy0218/miniconda3/envs/fred_workenv/lib/python3.9/site-packages/distributed/node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43781 instead
#   warnings.warn(
# /tmp/ipykernel_2198616/2190712997.py:24: ProplotWarning: rc setting 'linewidth' was renamed to 'meta.width' in version 0.8.
#   plot.rc.update({'figure.facecolor':'w','axes.labelweight':'ultralight',

# %%
############################################################################################################################################
# PCA_dict: Processed EOF objects; A_dict: Variable anomaly matrices; Af_dict: Flattened variable anomaly matrices
# *note that following EOF conventions, we derived EOFs with anomalies.
############################################################################################################################################
# Basic settings
folderpath='/work/FAC/FGSE/IDYST/tbeucler/default/freddy0218/TCGphy/2020_TC_CRF/dev/freddy0218/pca/output/uvwheat/'
expname = ['ctl','ncrf_36h','ncrf_60h','lwcrf']
varname = ['u','v','w']
nummem = [54,26,50,5,75,12,10]
#################################################################################
# 24-hr smoothing model
PCAdict = read_and_proc.depickle(folderpath+'PCA/ctl_PCA_dict1')
# Read files
flatvar = [read_and_proc.depickle(folderpath+'preproc/'+str(expname[i])+'_'+'smooth_preproc_dict1b_g') for i in range(len(expname))]
vardicts = maria_IO.input_output(PCAdict,folderpath,varname,nummem).readvar_separate(listdict=flatvar,varname=['u','v','w','qv','theta','hdia','rad'])
del flatvar#,thetavar
gc.collect()
#################################################################################
# Out:
# 235

# %%
from sklearn.feature_selection import SelectorMixin
from sklearn.metrics import r2_score
from sklearn.base import BaseEstimator, MetaEstimatorMixin, clone
from sklearn.model_selection import cross_val_score
import numpy as np
import gc
import importlib
importlib.reload(proc_mlrfcst)
importlib.reload(mlr)

class forwardfeatureadder(BaseEstimator,SelectorMixin,MetaEstimatorMixin):
    """Transformer to add feature at a sequential order
    Parameters:
    estimator: Regression model
    n_features_to_select: number of features to add to the model
    cv: how many folds would we want during cross-validation
    n_jobs: Parallelization
    startfeatures: Features we would like to include in the model without cross-validation [we do this to accentuate the role of heating]
    
    Output:
    self instance
    """
    def __init__(self,estimator,n_features_to_select=None,cv=5,n_jobs=None,startfeatures=None,PCAdict=None,Afdict=None,numcomp=None,LT=None,optigoal='surface',Xsurf=None,Ysurf=None):
        self.estimator = estimator
        self.n_features_to_select = n_features_to_select
        self.cv = cv
        self.n_jobs = n_jobs
        self.startfeatures = startfeatures
        self.PCAdict = PCAdict
        self.Afdict = Afdict
        self.numcomp = numcomp
        self.LT = LT
        self.optigoal = optigoal
        self.Xsurf=Xsurf
        self.Ysurf=Ysurf
    
    def get_real_winds(self):
        temp1,temp2,temp3,temp4 = proc_mlrfcst.retrieve_cartesian(PCA_dict=self.PCAdict,Af_dict=self.Afdict,numcomp=self.numcomp,LT=self.LT,
                            forecastPC=None).windrates_real(LT=self.LT)
        return temp1,temp2,temp3,temp4
    
    def convert_forecast_winds(self,yforecast=None):
        try:
            temp1,temp2,temp3,temp4 = proc_mlrfcst.retrieve_cartesian(PCA_dict=self.PCAdict,Af_dict=self.Afdict,numcomp=self.numcomp,LT=self.LT,
                                                                      forecastPC=yforecast).output_reshapeRECON(forecast_eig=yforecast[int(self.LT[i]-1)])
            return temp1,temp2,temp3,temp4
        except:
            temp1,temp2 = proc_mlrfcst.retrieve_cartesian(PCA_dict=self.PCAdict,Af_dict=self.Afdict,numcomp=self.numcomp,LT=self.LT,
                                                                      forecastPC=yforecast,target='surface').output_reshapeRECON(forecast_eig=yforecast)        
            return temp1,temp2
    
    def fit(self, X,y=None):
        """Learn features to select from X.
        X (n_samples,n_features): Training vectors
        Y (n_samples): Target values
        """
        # Define basic settings
        n_features = X.shape[1]
        current_mask = np.zeros(shape=n_features,dtype=bool)
        for index in self.startfeatures:
            current_mask[index] = True
        n_iteractions = self.n_features_to_select
        
        # Do forward selection
        addinput,r2 = [],[]
        clone_estimator = clone(self.estimator)
        for _ in range(n_iteractions):
            new_feature_idx,r2t = self.get_best_new_feature_R2based(clone_estimator,X,y,current_mask)
            #new_feature_idx = self.get_best_new_feature(clone_estimator,X,y,current_mask)
            r2.append(r2t)
            current_mask[new_feature_idx] = True
            addinput.append(current_mask)
        
        self.support_ = current_mask
        self.new_feature = new_feature_idx
        self.r2 = r2
        return self
    
    def get_best_new_feature(self,estimator,X,y,current_mask):
        candidate_feature_indices = np.flatnonzero(~current_mask)
        scores={}
        for feature_idx in candidate_feature_indices:
            candidate_mask = current_mask.copy()
            candidate_mask[feature_idx] = True
            
            # Add a new feature
            X_new = X[:,candidate_mask]
            # Improvement
            scores[feature_idx] = cross_val_score(estimator,X_new,y,cv=self.cv,scoring=None,n_jobs=self.n_jobs).mean()
        return max(scores,key=lambda feature_idx: scores[feature_idx])
    
    #--------------------------------------------------------------
    # To do -> Add featureselector based on r2
    # Candidate mask -> Xnew
    # fit linear model with (Xnew,y)
    # {output r2 term [time consideration => target: surface u/v]}...repeat for all u/v/w/theta members
    # get component index that results in best r2 score
    # --------[[Exit loops when r2 reaches 0.75?]]-----------------
    # add to mask during fitting 
    #---------------------------------------------------------------------------------------------------
    def get_best_new_feature_R2based(self,estimator,X,y,current_mask):             
        candidate_feature_indices = np.flatnonzero(~current_mask)
        scores={}
        for feature_idx in candidate_feature_indices:
            candidate_mask = current_mask.copy()
            candidate_mask[feature_idx] = True
            # Add a new feature
            X_new = X[:,candidate_mask]
            # Improvement
            LDTME = np.linspace(0,44,45)+1
            y_forecast = mlr.model_fitpredict(X_new,y,estimator,LDTME).modelfit(singleLT=True)[0].predict(X_new)
            #################################################################################################################################################################################################################
            # Forecast winds
            #################################################################################################################################################################################################################
            if self.optigoal=='surface':
                teMP1,teMP2 = self.convert_forecast_winds(y_forecast)
                teMP1s,teMP2s = (teMP1.reshape(teMP1.shape[0],39,360,167)[:,0,:,:]).reshape(teMP1.shape[0],360*167),(teMP2.reshape(teMP2.shape[0],39,360,167)[:,0,:,:]).reshape(teMP2.shape[0],360*167)
                del teMP1,teMP2
                gc.collect()
                
                scores[feature_idx] = r2_score(np.concatenate((self.Xsurf,self.Ysurf),axis=0),np.concatenate((teMP1s,teMP2s),axis=0))
            else:
                teMP1,teMP2,teMP3,teMP4 = self.convert_forecast_winds(y_forecast)                
                scores[feature_idx] = r2_score(np.concatenate((reteMP1,reteMP2,reteMP3,reteMP4),axis=0),np.concatenate((teMP1,teMP2,teMP3,teMP4),axis=0))
        return max(scores,key=lambda feature_idx: scores[feature_idx]),max(scores.values())
    
    def _get_support_mask(self):
        return self.support_

# %%
from tools.mlr import mlr,proc_mlrfcst
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SequentialFeatureSelector

path = '/work/FAC/FGSE/IDYST/tbeucler/default/freddy0218/TCGphy/2020_TC_CRF/dev/freddy0218/pca/output/complex/heatcomp_separate/'
path2 = '/work/FAC/FGSE/IDYST/tbeucler/default/freddy0218/TCGphy/2020_TC_CRF/dev/freddy0218/pca/output/complex/Q95_complex/'
file2 = [path+'inputoutput/'+'inputQ95_dict_smoo6_withtheta',path+'inputoutput/'+'outputQ95_dict_smoo6_withtheta']#,path+'NOIR_dict_smoo6_withtheta',path+'IR_dict_smoo6_withtheta']
mlr_inputdict,mlr_output = read_and_proc.depickle(file2[0]),read_and_proc.depickle(file2[1])

# %%
# Initiate model
nummem = [54,26,50,75]
linreg = LinearRegression()
mlrIN,mlrOUT = mlr.SimpleIOhandler(LT=24,auxIN=None).transform(mlr_inputdict['dtthuvw'],mlr_output)
reteMP1,reteMP2,_,_  = forwardfeatureadder(linreg,1,3,2,[int(obj) for obj in np.linspace(241-36,240,36)],PCAdict,vardicts,nummem,24,'surface').get_real_winds()
reteMP1s,reteMP2s = (reteMP1.reshape(reteMP1.shape[0],39,360,167)[:,0,:,:]).reshape(reteMP1.shape[0],360*167),(reteMP2.reshape(reteMP2.shape[0],39,360,167)[:,0,:,:]).reshape(reteMP2.shape[0],360*167)
del reteMP1,reteMP2
gc.collect()

# Train model
def generator():
    while True:
        yield

i=0
model,reducedX,new_feature = [],[],[]
holdmem = [int(obj) for obj in np.linspace(217,227-1,10)]
for i in (range(10)):#np.asarray(mlrIN).shape[1]-36)):
    #seq_temp = forwardfeatureadder(linreg,i+1,3,2,[int(obj) for obj in np.linspace(241-36,240,36)],\
    #                              PCAdict,vardicts,nummem,24,'surface',reteMP1s,reteMP2s).fit(np.asarray(mlrIN),mlrOUT)
    #seq_temp = forwardfeatureadder(linreg,i+1,3,2,[int(obj) for obj in np.linspace(241-36,240,36)],\
    #                              PCAdict,vardicts,nummem,24,'surface',None,None).fit(np.asarray(mlrIN),mlrOUT)
    seq_temp = forwardfeatureadder(linreg,1,5,2,holdmem,\
                                   PCAdict,vardicts,nummem,24,'surface',reteMP1s,reteMP2s).fit(np.asarray(mlrIN),mlrOUT)
    holdmem.append(seq_temp.new_feature)
    new_feature.append(seq_temp.new_feature)
    Xn = seq_temp.transform(np.asarray(mlrIN)) #Remove unimportant features
    ridge_reduced = LinearRegression().fit(Xn,mlrOUT) #Train model with reduced input
    model.append(ridge_reduced)
    reducedX.append(Xn)
    ####################################################################################################
    # Check r2 score
    ####################################################################################################
    #if r2_score(mlrOUT,ridge_reduced.predict(Xn))<=0.9:
    #    continue
    #else:
    #    break
# Out:
# Source path:... /tmp/ipykernel_2198616/2362939780.py
# Starting var:.. self = REPR FAILED
# Starting var:.. estimator = LinearRegression()
# Starting var:.. n_features_to_select = 1
# Starting var:.. cv = 3
# Starting var:.. n_jobs = 2
# Starting var:.. startfeatures = [205, 206, 207, 208, 209, 210, 211, 212, 213, 21...231, 232, 233, 234, 235, 236, 237, 238, 239, 240]
# Starting var:.. PCAdict = {'u': PCA(), 'v': PCA(), 'w': PCA(), 'qv': PCA()... PCA(), 'hdia': PCA(), 'rad': PCA(), 'ir': PCA()}
# Starting var:.. Afdict = {'ctl': [array([[  0.16094698,   0.38626236,   0...61916432e-05, -1.60627460e-05]], dtype=float32)]}
# Starting var:.. numcomp = [54, 26, 50, 75]
# Starting var:.. LT = 24
# Starting var:.. optigoal = 'surface'
# Starting var:.. Xsurf = None
# Starting var:.. Ysurf = None
# 15:30:32.390571 call        24 SOURCE IS UNAVAILABLE
# 15:30:32.511872 line        25 SOURCE IS UNAVAILABLE
# 15:30:32.525806 line        26 SOURCE IS UNAVAILABLE
# 15:30:32.589765 line        27 SOURCE IS UNAVAILABLE
# 15:30:32.661268 line        28 SOURCE IS UNAVAILABLE
# 15:30:32.675019 line        29 SOURCE IS UNAVAILABLE
# 15:30:32.791151 line        30 SOURCE IS UNAVAILABLE
# 15:30:32.806220 line        31 SOURCE IS UNAVAILABLE
# 15:30:32.897990 line        32 SOURCE IS UNAVAILABLE
# 15:30:32.971542 line        33 SOURCE IS UNAVAILABLE
# 15:30:32.985033 line        34 SOURCE IS UNAVAILABLE
# 15:30:33.004945 line        35 SOURCE IS UNAVAILABLE
# 15:30:33.088789 line        36 SOURCE IS UNAVAILABLE
# Modified var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....                             232, 233, 234, ...])
# 15:30:33.103965 return      36 SOURCE IS UNAVAILABLE
# Return value:.. None
# Elapsed time: 00:00:01.242758
# Starting var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....                             232, 233, 234, ...])
# 15:30:33.633391 call        38 SOURCE IS UNAVAILABLE
# 15:30:34.148976 line        39 SOURCE IS UNAVAILABLE
# 15:30:34.655939 line        40 SOURCE IS UNAVAILABLE
# 15:30:35.191834 line        39 SOURCE IS UNAVAILABLE
# 15:30:35.714700 line        40 SOURCE IS UNAVAILABLE
# 15:30:36.213209 line        39 SOURCE IS UNAVAILABLE
# New var:....... temp1 = array([[-1.45443855e-04, -1.48339327e-04, -1.511...32836862e-05, -3.44948857e-05, -3.47047713e-05]])
# New var:....... temp2 = array([[-1.23839886e-04, -1.28724884e-04, -1.320...36341799e-06, -3.11123069e-06, -4.35851514e-06]])
# New var:....... temp3 = array([[ 9.75932495e-08, -6.23074313e-08,  6.834...32290432e-08, -3.40027467e-07, -4.09793273e-07]])
# New var:....... temp4 = array([[ 1.31782144e-09,  1.76643004e-09,  2.883...52231149e-12,  1.54399357e-12,  1.54960028e-12]])
# 15:31:23.699106 line        41 SOURCE IS UNAVAILABLE
# 15:31:24.230249 return      41 SOURCE IS UNAVAILABLE
# Return value:.. (array([[-1.45443855e-04, -1.48339327e-04, -1.51...2231149e-12,  1.54399357e-12,  1.54960028e-12]]))
# Elapsed time: 00:00:51.078480
# Starting var:.. self = REPR FAILED
# Starting var:.. estimator = LinearRegression()
# Starting var:.. n_features_to_select = 1
# Starting var:.. cv = 5
# Starting var:.. n_jobs = 2
# Starting var:.. startfeatures = [217, 218, 219, 220, 221, 222, 223, 224, 225, 226]
# Starting var:.. PCAdict = {'u': PCA(), 'v': PCA(), 'w': PCA(), 'qv': PCA()... PCA(), 'hdia': PCA(), 'rad': PCA(), 'ir': PCA()}
# Starting var:.. Afdict = {'ctl': [array([[  0.16094698,   0.38626236,   0...61916432e-05, -1.60627460e-05]], dtype=float32)]}
# Starting var:.. numcomp = [54, 26, 50, 75]
# Starting var:.. LT = 24
# Starting var:.. optigoal = 'surface'
# Starting var:.. Xsurf = array([[-1.45443855e-04, -1.48339327e-04, -1.511...50758617e-05, -2.58700550e-05, -2.89075021e-05]])
# Starting var:.. Ysurf = array([[-1.23839886e-04, -1.28724884e-04, -1.320...87190917e-05,  3.56749638e-05,  3.29800778e-05]])
# 15:31:25.240344 call        24 SOURCE IS UNAVAILABLE
# 15:31:25.298929 line        25 SOURCE IS UNAVAILABLE
# 15:31:25.413074 line        26 SOURCE IS UNAVAILABLE
# 15:31:25.429716 line        27 SOURCE IS UNAVAILABLE
# 15:31:25.526930 line        28 SOURCE IS UNAVAILABLE
# 15:31:25.602989 line        29 SOURCE IS UNAVAILABLE
# 15:31:25.616885 line        30 SOURCE IS UNAVAILABLE
# 15:31:25.647429 line        31 SOURCE IS UNAVAILABLE
# 15:31:25.711630 line        32 SOURCE IS UNAVAILABLE
# 15:31:25.781647 line        33 SOURCE IS UNAVAILABLE
# 15:31:25.803878 line        34 SOURCE IS UNAVAILABLE
# 15:31:25.881398 line        35 SOURCE IS UNAVAILABLE
# 15:31:25.954049 line        36 SOURCE IS UNAVAILABLE
# Modified var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....224, 225,                                   226])
# 15:31:25.974576 return      36 SOURCE IS UNAVAILABLE
# Return value:.. None
# Elapsed time: 00:00:01.339082
# Starting var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....224, 225,                                   226])
# Starting var:.. X = array([[ 1.0768255 ,  1.8517579 ,  1.775063  , ....       -0.06805734,  0.16387165]], dtype=float32)
# Starting var:.. y = [array([ 6.85786495e-04, -7.99670410e-02, -5.267...73e-05, -2.80468795e-04,       -1.69652590e-04])]
# 15:31:26.579675 call        53 SOURCE IS UNAVAILABLE
# 15:31:28.524714 line        59 SOURCE IS UNAVAILABLE
# New var:....... n_features = 227
# 15:31:30.422814 line        60 SOURCE IS UNAVAILABLE
# New var:....... current_mask = array([False, False, False, False, False, False,... False, False, False, False,       False, False])
# 15:31:32.380854 line        61 SOURCE IS UNAVAILABLE
# New var:....... index = 217
# 15:31:34.296748 line        62 SOURCE IS UNAVAILABLE
# 15:31:35.545596 line        61 SOURCE IS UNAVAILABLE
# Modified var:.. index = 218
# 15:31:37.356871 line        62 SOURCE IS UNAVAILABLE
# 15:31:39.345895 line        61 SOURCE IS UNAVAILABLE
# Modified var:.. index = 219
# 15:31:41.210156 line        62 SOURCE IS UNAVAILABLE
# 15:31:43.108843 line        61 SOURCE IS UNAVAILABLE
# Modified var:.. index = 220
# 15:31:45.028121 line        62 SOURCE IS UNAVAILABLE
# 15:31:46.980007 line        61 SOURCE IS UNAVAILABLE
# Modified var:.. index = 221
# 15:31:48.875231 line        62 SOURCE IS UNAVAILABLE
# Modified var:.. current_mask = array([False, False, False, False, False, False,...  True, False, False, False,       False, False])
# 15:31:50.776559 line        61 SOURCE IS UNAVAILABLE
# Modified var:.. index = 222
# 15:31:52.687083 line        62 SOURCE IS UNAVAILABLE
# Modified var:.. current_mask = array([False, False, False, False, False, False,...  True,  True, False, False,       False, False])
# 15:31:54.631725 line        61 SOURCE IS UNAVAILABLE
# Modified var:.. index = 223
# 15:31:56.490127 line        62 SOURCE IS UNAVAILABLE
# Modified var:.. current_mask = array([False, False, False, False, False, False,...  True,  True,  True, False,       False, False])
# 15:31:58.370311 line        61 SOURCE IS UNAVAILABLE
# Modified var:.. index = 224
# 15:32:00.233871 line        62 SOURCE IS UNAVAILABLE
# Modified var:.. current_mask = array([False, False, False, False, False, False,...  True,  True,  True,  True,       False, False])
# 15:32:02.142647 line        61 SOURCE IS UNAVAILABLE
# Modified var:.. index = 225
# 15:32:04.017710 line        62 SOURCE IS UNAVAILABLE
# Modified var:.. current_mask = array([False, False, False, False, False, False,...  True,  True,  True,  True,        True, False])
# 15:32:05.848955 line        61 SOURCE IS UNAVAILABLE
# Modified var:.. index = 226
# 15:32:07.690724 line        62 SOURCE IS UNAVAILABLE
# Modified var:.. current_mask = array([False, False, False, False, False, False,...  True,  True,  True,  True,        True,  True])
# 15:32:09.566502 line        61 SOURCE IS UNAVAILABLE
# 15:32:11.406852 line        63 SOURCE IS UNAVAILABLE
# New var:....... n_iteractions = 1
# 15:32:13.293440 line        66 SOURCE IS UNAVAILABLE
# New var:....... addinput = []
# New var:....... r2 = []
# 15:32:15.167679 line        67 SOURCE IS UNAVAILABLE
# New var:....... clone_estimator = LinearRegression()
# 15:32:16.985853 line        68 SOURCE IS UNAVAILABLE
# New var:....... _ = 0
# 15:32:18.863786 line        69 SOURCE IS UNAVAILABLE
#     Starting var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....224, 225,                                   226])
#     Starting var:.. estimator = LinearRegression()
#     Starting var:.. X = array([[ 1.0768255 ,  1.8517579 ,  1.775063  , ....       -0.06805734,  0.16387165]], dtype=float32)
#     Starting var:.. y = [array([ 6.85786495e-04, -7.99670410e-02, -5.267...73e-05, -2.80468795e-04,       -1.69652590e-04])]
#     Starting var:.. current_mask = array([False, False, False, False, False, False,...  True,  True,  True,  True,        True,  True])
#     15:32:20.718650 call       102 SOURCE IS UNAVAILABLE
#     15:32:22.618511 line       103 SOURCE IS UNAVAILABLE
#     New var:....... candidate_feature_indices = array([  0,   1,   2,   3,   4,   5,   6,   7,  ...    208, 209, 210, 211, 212, 213, 214, 215, 216])
#     15:32:24.452282 line       104 SOURCE IS UNAVAILABLE
#     New var:....... scores = {}
#     15:32:26.309240 line       105 SOURCE IS UNAVAILABLE
#     New var:....... feature_idx = 0
#     15:32:28.193792 line       106 SOURCE IS UNAVAILABLE
#     New var:....... candidate_mask = array([False, False, False, False, False, False,...  True,  True,  True,  True,        True,  True])
#     15:32:30.017518 line       107 SOURCE IS UNAVAILABLE
#     Modified var:.. candidate_mask = array([ True, False, False, False, False, False,...  True,  True,  True,  True,        True,  True])
#     15:32:31.883602 line       109 SOURCE IS UNAVAILABLE
#     New var:....... X_new = array([[ 1.0768255 , -0.58037513,  0.36278033, ....       -0.06805734,  0.16387165]], dtype=float32)
#     15:32:33.735637 line       111 SOURCE IS UNAVAILABLE
#     New var:....... LDTME = array([ 1.,  2.,  3.,  4.,  5.,  6.,  7.,  8.,  ...., 38., 39.,       40., 41., 42., 43., 44., 45.])
#     15:32:35.659423 line       112 SOURCE IS UNAVAILABLE
#     New var:....... y_forecast = array([[-6.5753534e-03, -5.8253258e-02, -4.93031... -9.7796641e-05, -7.8821846e-05]], dtype=float32)
#     15:32:37.751515 line       116 SOURCE IS UNAVAILABLE
#     15:32:39.571823 line       117 SOURCE IS UNAVAILABLE
#         Starting var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....224, 225,                                   226])
#         Starting var:.. yforecast = array([[-6.5753534e-03, -5.8253258e-02, -4.93031... -9.7796641e-05, -7.8821846e-05]], dtype=float32)
#         15:32:41.452098 call        43 SOURCE IS UNAVAILABLE
#         15:32:41.976569 line        44 SOURCE IS UNAVAILABLE
#         15:32:42.509992 line        45 SOURCE IS UNAVAILABLE
#         15:32:42.991794 line        46 SOURCE IS UNAVAILABLE
#         15:32:43.509395 line        45 SOURCE IS UNAVAILABLE
#         15:32:44.060127 line        46 SOURCE IS UNAVAILABLE
#         15:32:44.572602 exception   46 SOURCE IS UNAVAILABLE
#         Exception:..... TypeError: 'int' object is not subscriptable
#         15:32:45.090773 line        48 SOURCE IS UNAVAILABLE
#         15:32:45.636289 line        49 SOURCE IS UNAVAILABLE
#         15:32:46.158294 line        50 SOURCE IS UNAVAILABLE
#         15:32:46.664967 line        49 SOURCE IS UNAVAILABLE
#         15:32:47.176404 line        50 SOURCE IS UNAVAILABLE
#         15:32:47.702437 line        49 SOURCE IS UNAVAILABLE
#         New var:....... temp1 = array([[-2.73574406e-04,  3.01952241e-09, -1.849...1.39496406e-05, -1.41461705e-05]], dtype=float32)
#         New var:....... temp2 = array([[-1.60716445e-06, -9.36944052e-05, -1.113...8.03385956e-06,  7.97604116e-06]], dtype=float32)
#         15:33:02.318397 line        51 SOURCE IS UNAVAILABLE
#         15:33:02.901456 return      51 SOURCE IS UNAVAILABLE
#         Return value:.. (array([[-2.73574406e-04,  3.01952241e-09, -1.84....03385956e-06,  7.97604116e-06]], dtype=float32))
#         Elapsed time: 00:00:21.959313
#     New var:....... teMP1 = array([[-2.73574406e-04,  3.01952241e-09, -1.849...1.39496406e-05, -1.41461705e-05]], dtype=float32)
#     New var:....... teMP2 = array([[-1.60716445e-06, -9.36944052e-05, -1.113...8.03385956e-06,  7.97604116e-06]], dtype=float32)
#     15:33:03.411513 line       118 SOURCE IS UNAVAILABLE
#     New var:....... teMP1s = array([[-2.7357441e-04,  3.0195224e-09, -1.84974... -3.5678335e-05, -3.8715913e-05]], dtype=float32)
#     New var:....... teMP2s = array([[-1.60716445e-06, -9.36944052e-05, -1.113...2.99452422e-05,  3.12275988e-05]], dtype=float32)
#     15:33:05.279261 line       119 SOURCE IS UNAVAILABLE
#     15:33:07.110588 line       120 SOURCE IS UNAVAILABLE
#     15:33:09.409919 line       122 SOURCE IS UNAVAILABLE
#     Modified var:.. scores = {0: 0.708665081653992}
#     15:33:12.477038 line       105 SOURCE IS UNAVAILABLE
#     Modified var:.. feature_idx = 1
#     15:33:14.376703 line       106 SOURCE IS UNAVAILABLE
#     Modified var:.. candidate_mask = array([False, False, False, False, False, False,...  True,  True,  True,  True,        True,  True])
#     15:33:16.235285 line       107 SOURCE IS UNAVAILABLE
#     Modified var:.. candidate_mask = array([False,  True, False, False, False, False,...  True,  True,  True,  True,        True,  True])
#     15:33:18.090731 line       109 SOURCE IS UNAVAILABLE
#     Modified var:.. X_new = array([[ 1.8517579 , -0.58037513,  0.36278033, ....       -0.06805734,  0.16387165]], dtype=float32)
#     15:33:19.981230 line       111 SOURCE IS UNAVAILABLE
#     15:33:21.826486 line       112 SOURCE IS UNAVAILABLE
#     Modified var:.. y_forecast = array([[ 7.6621361e-03, -6.9225982e-02, -2.38875... -2.1661802e-04, -8.8356523e-05]], dtype=float32)
#     15:33:23.721745 line       116 SOURCE IS UNAVAILABLE
#     15:33:25.574156 line       117 SOURCE IS UNAVAILABLE
#         Starting var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....224, 225,                                   226])
#         Starting var:.. yforecast = array([[ 7.6621361e-03, -6.9225982e-02, -2.38875... -2.1661802e-04, -8.8356523e-05]], dtype=float32)
#         15:33:27.476462 call        43 SOURCE IS UNAVAILABLE
#         15:33:27.978402 line        44 SOURCE IS UNAVAILABLE
#         15:33:28.501234 line        45 SOURCE IS UNAVAILABLE
#         15:33:29.014777 line        46 SOURCE IS UNAVAILABLE
#         15:33:29.570010 line        45 SOURCE IS UNAVAILABLE
#         15:33:30.107562 line        46 SOURCE IS UNAVAILABLE
#         15:33:30.581699 exception   46 SOURCE IS UNAVAILABLE
#         Exception:..... TypeError: 'int' object is not subscriptable
#         15:33:31.137677 line        48 SOURCE IS UNAVAILABLE
#         15:33:31.663857 line        49 SOURCE IS UNAVAILABLE
#         15:33:32.210303 line        50 SOURCE IS UNAVAILABLE
#         15:33:32.696538 line        49 SOURCE IS UNAVAILABLE
#         15:33:33.263386 line        50 SOURCE IS UNAVAILABLE
#         15:33:33.759413 line        49 SOURCE IS UNAVAILABLE
#         New var:....... temp1 = array([[-1.7484908e-04, -6.6177563e-05, -1.73944... -2.4439059e-05, -2.4464272e-05]], dtype=float32)
#         New var:....... temp2 = array([[-5.1895990e-05, -1.2722904e-04, -1.42942... -3.9781676e-06, -4.1884091e-06]], dtype=float32)
#         15:33:48.461733 line        51 SOURCE IS UNAVAILABLE
#         15:33:48.977453 return      51 SOURCE IS UNAVAILABLE
#         Return value:.. (array([[-1.7484908e-04, -6.6177563e-05, -1.7394...-3.9781676e-06, -4.1884091e-06]], dtype=float32))
#         Elapsed time: 00:00:22.065141
#     New var:....... teMP1 = array([[-1.7484908e-04, -6.6177563e-05, -1.73944... -2.4439059e-05, -2.4464272e-05]], dtype=float32)
#     New var:....... teMP2 = array([[-5.1895990e-05, -1.2722904e-04, -1.42942... -3.9781676e-06, -4.1884091e-06]], dtype=float32)
#     15:33:49.541679 line       118 SOURCE IS UNAVAILABLE
#     Modified var:.. teMP1s = array([[-1.7484908e-04, -6.6177563e-05, -1.73944... -4.1352792e-05, -4.4680633e-05]], dtype=float32)
#     Modified var:.. teMP2s = array([[-5.1895990e-05, -1.2722904e-04, -1.42942...  1.5020305e-05,  1.5802960e-05]], dtype=float32)
#     15:33:51.467593 line       119 SOURCE IS UNAVAILABLE
#     15:33:53.366027 line       120 SOURCE IS UNAVAILABLE
#     15:33:55.663406 line       122 SOURCE IS UNAVAILABLE
#     Modified var:.. scores = {0: 0.708665081653992, 1: 0.7268257973338567}
#     15:33:58.659644 line       105 SOURCE IS UNAVAILABLE
#     Modified var:.. feature_idx = 2
#     15:34:00.589322 line       106 SOURCE IS UNAVAILABLE
#     Modified var:.. candidate_mask = array([False, False, False, False, False, False,...  True,  True,  True,  True,        True,  True])
#     15:34:02.463199 line       107 SOURCE IS UNAVAILABLE
#     Modified var:.. candidate_mask = array([False, False,  True, False, False, False,...  True,  True,  True,  True,        True,  True])
#     15:34:04.316439 line       109 SOURCE IS UNAVAILABLE
#     Modified var:.. X_new = array([[ 1.775063  , -0.58037513,  0.36278033, ....       -0.06805734,  0.16387165]], dtype=float32)
#     15:34:06.155657 line       111 SOURCE IS UNAVAILABLE
#     15:34:08.076364 line       112 SOURCE IS UNAVAILABLE
#     Modified var:.. y_forecast = array([[-6.8024844e-03, -7.0756838e-02, -5.93847... -1.6429523e-04, -9.3343377e-05]], dtype=float32)
#     15:34:09.962961 line       116 SOURCE IS UNAVAILABLE
#     15:34:11.846208 line       117 SOURCE IS UNAVAILABLE
#         Starting var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....224, 225,                                   226])
#         Starting var:.. yforecast = array([[-6.8024844e-03, -7.0756838e-02, -5.93847... -1.6429523e-04, -9.3343377e-05]], dtype=float32)
#         15:34:13.747682 call        43 SOURCE IS UNAVAILABLE
#         15:34:14.248783 line        44 SOURCE IS UNAVAILABLE
#         15:34:14.801926 line        45 SOURCE IS UNAVAILABLE
#         15:34:15.325724 line        46 SOURCE IS UNAVAILABLE
#         15:34:15.826202 line        45 SOURCE IS UNAVAILABLE
#         15:34:16.379178 line        46 SOURCE IS UNAVAILABLE
#         15:34:16.915499 exception   46 SOURCE IS UNAVAILABLE
#         Exception:..... TypeError: 'int' object is not subscriptable
#         15:34:17.444238 line        48 SOURCE IS UNAVAILABLE
#         15:34:17.969192 line        49 SOURCE IS UNAVAILABLE
#         15:34:18.556373 line        50 SOURCE IS UNAVAILABLE
#         15:34:19.087583 line        49 SOURCE IS UNAVAILABLE
#         15:34:19.605764 line        50 SOURCE IS UNAVAILABLE
#         15:34:20.126723 line        49 SOURCE IS UNAVAILABLE
#         New var:....... temp1 = array([[-3.3422292e-04, -5.5842778e-05, -3.23867... -1.5706824e-05, -1.5867541e-05]], dtype=float32)
#         New var:....... temp2 = array([[-2.1351996e-05, -1.3107303e-04, -1.46898...  2.2530728e-06,  2.0701614e-06]], dtype=float32)
#         15:34:35.065433 line        51 SOURCE IS UNAVAILABLE
#         15:34:35.591829 return      51 SOURCE IS UNAVAILABLE
#         Return value:.. (array([[-3.3422292e-04, -5.5842778e-05, -3.2386... 2.2530728e-06,  2.0701614e-06]], dtype=float32))
#         Elapsed time: 00:00:22.378458
#     New var:....... teMP1 = array([[-3.3422292e-04, -5.5842778e-05, -3.23867... -1.5706824e-05, -1.5867541e-05]], dtype=float32)
#     New var:....... teMP2 = array([[-2.1351996e-05, -1.3107303e-04, -1.46898...  2.2530728e-06,  2.0701614e-06]], dtype=float32)
#     15:34:36.126215 line       118 SOURCE IS UNAVAILABLE
#     Modified var:.. teMP1s = array([[-3.3422292e-04, -5.5842778e-05, -3.23867... -2.9040466e-05, -3.2517240e-05]], dtype=float32)
#     Modified var:.. teMP2s = array([[-2.1351996e-05, -1.3107303e-04, -1.46898...  2.3304741e-05,  2.4246265e-05]], dtype=float32)
#     15:34:38.115836 line       119 SOURCE IS UNAVAILABLE
#     15:34:39.984525 line       120 SOURCE IS UNAVAILABLE
#     15:34:42.314302 line       122 SOURCE IS UNAVAILABLE
#     Modified var:.. scores = {0: 0.708665081653992, 1: 0.7268257973338567, 2: 0.7006567541311743}
#     15:34:45.403767 line       105 SOURCE IS UNAVAILABLE
#     Modified var:.. feature_idx = 3
#     15:34:47.293295 line       106 SOURCE IS UNAVAILABLE
#     Modified var:.. candidate_mask = array([False, False, False, False, False, False,...  True,  True,  True,  True,        True,  True])
#     15:34:49.171578 line       107 SOURCE IS UNAVAILABLE
#     Modified var:.. candidate_mask = array([False, False, False,  True, False, False,...  True,  True,  True,  True,        True,  True])
#     15:34:51.111400 line       109 SOURCE IS UNAVAILABLE
#     Modified var:.. X_new = array([[-0.21444364, -0.58037513,  0.36278033, ....       -0.06805734,  0.16387165]], dtype=float32)
#     15:34:53.015412 line       111 SOURCE IS UNAVAILABLE
#     15:34:54.905976 line       112 SOURCE IS UNAVAILABLE
#     Modified var:.. y_forecast = array([[ 1.0441147e-02, -7.3761217e-02, -1.98302... -1.2163093e-04, -8.7188637e-05]], dtype=float32)
#     15:34:56.810377 line       116 SOURCE IS UNAVAILABLE
#     15:34:58.744517 line       117 SOURCE IS UNAVAILABLE
#         Starting var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....224, 225,                                   226])
#         Starting var:.. yforecast = array([[ 1.0441147e-02, -7.3761217e-02, -1.98302... -1.2163093e-04, -8.7188637e-05]], dtype=float32)
#         15:35:00.611120 call        43 SOURCE IS UNAVAILABLE
#         15:35:01.148237 line        44 SOURCE IS UNAVAILABLE
#         15:35:01.679045 line        45 SOURCE IS UNAVAILABLE
#         15:35:02.195395 line        46 SOURCE IS UNAVAILABLE
#         15:35:02.736490 line        45 SOURCE IS UNAVAILABLE
#         15:35:03.246529 line        46 SOURCE IS UNAVAILABLE
#         15:35:03.835837 exception   46 SOURCE IS UNAVAILABLE
#         Exception:..... TypeError: 'int' object is not subscriptable
#         15:35:04.343254 line        48 SOURCE IS UNAVAILABLE
#         15:35:04.920771 line        49 SOURCE IS UNAVAILABLE
#         15:35:05.450269 line        50 SOURCE IS UNAVAILABLE
#         15:35:05.977088 line        49 SOURCE IS UNAVAILABLE
#         15:35:06.547587 line        50 SOURCE IS UNAVAILABLE
#         15:35:07.047528 line        49 SOURCE IS UNAVAILABLE
#         New var:....... temp1 = array([[-1.62479526e-04, -9.40537720e-05, -1.828...2.63257771e-05, -2.63166639e-05]], dtype=float32)
#         New var:....... temp2 = array([[-6.53283496e-05, -1.44289399e-04, -1.594...4.32820741e-07, -9.60882289e-07]], dtype=float32)
#         15:35:22.159300 line        51 SOURCE IS UNAVAILABLE
#         15:35:22.730721 return      51 SOURCE IS UNAVAILABLE
#         Return value:.. (array([[-1.62479526e-04, -9.40537720e-05, -1.82....32820741e-07, -9.60882289e-07]], dtype=float32))
#         Elapsed time: 00:00:22.678070
#     New var:....... teMP1 = array([[-1.62479526e-04, -9.40537720e-05, -1.828...2.63257771e-05, -2.63166639e-05]], dtype=float32)
#     New var:....... teMP2 = array([[-6.53283496e-05, -1.44289399e-04, -1.594...4.32820741e-07, -9.60882289e-07]], dtype=float32)
#     15:35:23.289266 line       118 SOURCE IS UNAVAILABLE
#     Modified var:.. teMP1s = array([[-1.62479526e-04, -9.40537720e-05, -1.828...3.52272982e-05, -3.83142142e-05]], dtype=float32)
#     Modified var:.. teMP2s = array([[-6.53283496e-05, -1.44289399e-04, -1.594...2.65356302e-05,  2.71154677e-05]], dtype=float32)
#     15:35:25.238980 line       119 SOURCE IS UNAVAILABLE
#     15:35:27.121319 line       120 SOURCE IS UNAVAILABLE
#     15:35:29.492418 line       122 SOURCE IS UNAVAILABLE
#     Modified var:.. scores = {0: 0.708665081653992, 1: 0.7268257973338567, 2: 0.7006567541311743, 3: 0.7111247154746206}
#     15:35:32.657153 line       105 SOURCE IS UNAVAILABLE
#     Modified var:.. feature_idx = 4
#     15:35:34.568857 line       106 SOURCE IS UNAVAILABLE
#     Modified var:.. candidate_mask = array([False, False, False, False, False, False,...  True,  True,  True,  True,        True,  True])
#     15:35:36.466448 line       107 SOURCE IS UNAVAILABLE
#     Modified var:.. candidate_mask = array([False, False, False, False,  True, False,...  True,  True,  True,  True,        True,  True])
#     15:35:38.337664 line       109 SOURCE IS UNAVAILABLE
#     Modified var:.. X_new = array([[ 0.45520675, -0.58037513,  0.36278033, ....       -0.06805734,  0.16387165]], dtype=float32)
#     15:35:40.151996 line       111 SOURCE IS UNAVAILABLE
#     15:35:42.045734 line       112 SOURCE IS UNAVAILABLE
#     Modified var:.. y_forecast = array([[ 7.89009035e-03, -7.01588616e-02, -2.476...2.89369957e-04, -1.00187361e-04]], dtype=float32)
#     15:35:43.920696 line       116 SOURCE IS UNAVAILABLE
#     15:35:45.797159 line       117 SOURCE IS UNAVAILABLE
#         Starting var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....224, 225,                                   226])
#         Starting var:.. yforecast = array([[ 7.89009035e-03, -7.01588616e-02, -2.476...2.89369957e-04, -1.00187361e-04]], dtype=float32)
#         15:35:47.614869 call        43 SOURCE IS UNAVAILABLE
#         15:35:48.136631 line        44 SOURCE IS UNAVAILABLE
#         15:35:48.627693 line        45 SOURCE IS UNAVAILABLE
#         15:35:49.188666 line        46 SOURCE IS UNAVAILABLE
#         15:35:49.667574 line        45 SOURCE IS UNAVAILABLE
#         15:35:50.181287 line        46 SOURCE IS UNAVAILABLE
#         15:35:50.692826 exception   46 SOURCE IS UNAVAILABLE
#         Exception:..... TypeError: 'int' object is not subscriptable
#         15:35:51.232761 line        48 SOURCE IS UNAVAILABLE
#         15:35:51.733232 line        49 SOURCE IS UNAVAILABLE
#         15:35:52.250573 line        50 SOURCE IS UNAVAILABLE
#         15:35:52.807154 line        49 SOURCE IS UNAVAILABLE
#         15:35:53.305165 line        50 SOURCE IS UNAVAILABLE
#         15:35:53.814110 line        49 SOURCE IS UNAVAILABLE
#         New var:....... temp1 = array([[-1.8464799e-04, -8.4688094e-05, -1.72526... -2.6929381e-05, -2.6900825e-05]], dtype=float32)
#         New var:....... temp2 = array([[-5.60111985e-05, -1.29195134e-04, -1.433...7.68698737e-06, -7.81347717e-06]], dtype=float32)
#         15:36:08.397207 line        51 SOURCE IS UNAVAILABLE
#         15:36:08.925343 return      51 SOURCE IS UNAVAILABLE
#         Return value:.. (array([[-1.8464799e-04, -8.4688094e-05, -1.7252....68698737e-06, -7.81347717e-06]], dtype=float32))
#         Elapsed time: 00:00:21.869442
#     New var:....... teMP1 = array([[-1.8464799e-04, -8.4688094e-05, -1.72526... -2.6929381e-05, -2.6900825e-05]], dtype=float32)
#     New var:....... teMP2 = array([[-5.60111985e-05, -1.29195134e-04, -1.433...7.68698737e-06, -7.81347717e-06]], dtype=float32)
#     15:36:09.484349 line       118 SOURCE IS UNAVAILABLE
#     Modified var:.. teMP1s = array([[-1.8464799e-04, -8.4688094e-05, -1.72526... -4.2725012e-05, -4.6836256e-05]], dtype=float32)
#     Modified var:.. teMP2s = array([[-5.60111985e-05, -1.29195134e-04, -1.433...9.00208488e-06,  9.66595690e-06]], dtype=float32)
#     15:36:11.343602 line       119 SOURCE IS UNAVAILABLE
#     15:36:13.207425 line       120 SOURCE IS UNAVAILABLE
#     15:36:15.445411 line       122 SOURCE IS UNAVAILABLE
#     Modified var:.. scores = {0: 0.708665081653992, 1: 0.7268257973338567, 2:...43, 3: 0.7111247154746206, 4: 0.7090070623898564}
#     15:36:18.494405 line       105 SOURCE IS UNAVAILABLE
#     Modified var:.. feature_idx = 5
#     15:36:20.289361 line       106 SOURCE IS UNAVAILABLE
#     Modified var:.. candidate_mask = array([False, False, False, False, False, False,...  True,  True,  True,  True,        True,  True])
#     15:36:22.128534 line       107 SOURCE IS UNAVAILABLE
#     Modified var:.. candidate_mask = array([False, False, False, False, False,  True,...  True,  True,  True,  True,        True,  True])
#     15:36:23.956168 line       109 SOURCE IS UNAVAILABLE
#     Modified var:.. X_new = array([[ 0.5809656 , -0.58037513,  0.36278033, ....       -0.06805734,  0.16387165]], dtype=float32)
#     15:36:25.789079 line       111 SOURCE IS UNAVAILABLE
#     15:36:27.679125 line       112 SOURCE IS UNAVAILABLE
#     Modified var:.. y_forecast = array([[ 1.4107149e-02, -8.5321188e-02, -1.38189... -2.6766540e-04, -9.6299598e-05]], dtype=float32)
#     15:36:29.541744 line       116 SOURCE IS UNAVAILABLE
#     15:36:31.373973 line       117 SOURCE IS UNAVAILABLE
#         Starting var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....224, 225,                                   226])
#         Starting var:.. yforecast = array([[ 1.4107149e-02, -8.5321188e-02, -1.38189... -2.6766540e-04, -9.6299598e-05]], dtype=float32)
#         15:36:33.209838 call        43 SOURCE IS UNAVAILABLE
#         15:36:33.716283 line        44 SOURCE IS UNAVAILABLE
#         15:36:34.278083 line        45 SOURCE IS UNAVAILABLE
#         15:36:34.722294 line        46 SOURCE IS UNAVAILABLE
#         15:36:35.247291 line        45 SOURCE IS UNAVAILABLE
#         15:36:35.801886 line        46 SOURCE IS UNAVAILABLE
#         15:36:36.303038 exception   46 SOURCE IS UNAVAILABLE
#         Exception:..... TypeError: 'int' object is not subscriptable
#         15:36:36.806063 line        48 SOURCE IS UNAVAILABLE
#         15:36:37.296588 line        49 SOURCE IS UNAVAILABLE
#         15:36:37.879340 line        50 SOURCE IS UNAVAILABLE
#         15:36:38.398558 line        49 SOURCE IS UNAVAILABLE
#         15:36:38.863115 line        50 SOURCE IS UNAVAILABLE
#         15:36:39.427296 line        49 SOURCE IS UNAVAILABLE
#         New var:....... temp1 = array([[-1.50433945e-04, -1.96708017e-04, -1.341...2.59408898e-05, -2.57911815e-05]], dtype=float32)
#         New var:....... temp2 = array([[-9.7714794e-05, -1.9127349e-04, -1.97156... -5.2995288e-06, -5.3676949e-06]], dtype=float32)
#         15:36:53.935864 line        51 SOURCE IS UNAVAILABLE
#         15:36:54.480209 return      51 SOURCE IS UNAVAILABLE
#         Return value:.. (array([[-1.50433945e-04, -1.96708017e-04, -1.34...-5.2995288e-06, -5.3676949e-06]], dtype=float32))
#         Elapsed time: 00:00:21.788926
#     New var:....... teMP1 = array([[-1.50433945e-04, -1.96708017e-04, -1.341...2.59408898e-05, -2.57911815e-05]], dtype=float32)
#     New var:....... teMP2 = array([[-9.7714794e-05, -1.9127349e-04, -1.97156... -5.2995288e-06, -5.3676949e-06]], dtype=float32)
#     15:36:54.998841 line       118 SOURCE IS UNAVAILABLE
#     Modified var:.. teMP1s = array([[-1.50433945e-04, -1.96708017e-04, -1.341...3.84111736e-05, -4.22996818e-05]], dtype=float32)
#     Modified var:.. teMP2s = array([[-9.77147938e-05, -1.91273488e-04, -1.971...1.06857042e-05,  1.13011201e-05]], dtype=float32)
#     15:36:56.909168 line       119 SOURCE IS UNAVAILABLE
#     15:36:58.791787 line       120 SOURCE IS UNAVAILABLE
#     15:37:01.028373 line       122 SOURCE IS UNAVAILABLE
#     Modified var:.. scores = {0: 0.708665081653992, 1: 0.7268257973338567, 2:...06, 4: 0.7090070623898564, 5: 0.7137803044308542}
#     15:37:04.026495 line       105 SOURCE IS UNAVAILABLE
#     Modified var:.. feature_idx = 6
#     15:37:05.948698 line       106 SOURCE IS UNAVAILABLE
#     Modified var:.. candidate_mask = array([False, False, False, False, False, False,...  True,  True,  True,  True,        True,  True])
#     15:37:07.800017 line       107 SOURCE IS UNAVAILABLE
#     15:37:09.607229 line       109 SOURCE IS UNAVAILABLE
#     Modified var:.. X_new = array([[-2.175327  , -0.58037513,  0.36278033, ....       -0.06805734,  0.16387165]], dtype=float32)
#     15:37:11.465361 line       111 SOURCE IS UNAVAILABLE
#     15:37:13.302650 line       112 SOURCE IS UNAVAILABLE
#     Modified var:.. y_forecast = array([[ 1.11127682e-02, -7.44761601e-02, -2.112...2.33068684e-04, -9.51967886e-05]], dtype=float32)
#     15:37:15.230748 line       116 SOURCE IS UNAVAILABLE
#     15:37:17.086067 line       117 SOURCE IS UNAVAILABLE
#         Starting var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....224, 225,                                   226])
#         Starting var:.. yforecast = array([[ 1.11127682e-02, -7.44761601e-02, -2.112...2.33068684e-04, -9.51967886e-05]], dtype=float32)
#         15:37:18.988715 call        43 SOURCE IS UNAVAILABLE
#         15:37:19.449907 line        44 SOURCE IS UNAVAILABLE
#         15:37:19.976333 line        45 SOURCE IS UNAVAILABLE
#         15:37:20.492870 line        46 SOURCE IS UNAVAILABLE
#         15:37:20.984645 line        45 SOURCE IS UNAVAILABLE
#         15:37:21.514373 line        46 SOURCE IS UNAVAILABLE
#         15:37:22.039242 exception   46 SOURCE IS UNAVAILABLE
#         Exception:..... TypeError: 'int' object is not subscriptable
#         15:37:22.592143 line        48 SOURCE IS UNAVAILABLE
#         15:37:23.108304 line        49 SOURCE IS UNAVAILABLE
#         15:37:23.624189 line        50 SOURCE IS UNAVAILABLE
#         15:37:24.134861 line        49 SOURCE IS UNAVAILABLE
#         15:37:24.654875 line        50 SOURCE IS UNAVAILABLE
#         15:37:25.195066 line        49 SOURCE IS UNAVAILABLE
#         New var:....... temp1 = array([[-1.6965379e-04, -1.1484802e-04, -1.62762... -2.4381723e-05, -2.4409335e-05]], dtype=float32)
#         New var:....... temp2 = array([[-6.8035544e-05, -1.4398026e-04, -1.56010... -4.7890453e-06, -4.9372497e-06]], dtype=float32)
#         15:37:39.925395 line        51 SOURCE IS UNAVAILABLE
#         15:37:40.482142 return      51 SOURCE IS UNAVAILABLE
#         Return value:.. (array([[-1.6965379e-04, -1.1484802e-04, -1.6276...-4.7890453e-06, -4.9372497e-06]], dtype=float32))
#         Elapsed time: 00:00:21.979582
#     New var:....... teMP1 = array([[-1.6965379e-04, -1.1484802e-04, -1.62762... -2.4381723e-05, -2.4409335e-05]], dtype=float32)
#     New var:....... teMP2 = array([[-6.8035544e-05, -1.4398026e-04, -1.56010... -4.7890453e-06, -4.9372497e-06]], dtype=float32)
#     15:37:40.968440 line       118 SOURCE IS UNAVAILABLE
#     Modified var:.. teMP1s = array([[-1.6965379e-04, -1.1484802e-04, -1.62762... -4.4153665e-05, -4.7765763e-05]], dtype=float32)
#     Modified var:.. teMP2s = array([[-6.80355442e-05, -1.43980258e-04, -1.560...1.40231250e-05,  1.49628995e-05]], dtype=float32)
#     15:37:42.850169 line       119 SOURCE IS UNAVAILABLE
#     15:37:44.722270 line       120 SOURCE IS UNAVAILABLE
#     15:37:46.998707 line       122 SOURCE IS UNAVAILABLE
#     Modified var:.. scores = {0: 0.708665081653992, 1: 0.7268257973338567, 2:...64, 5: 0.7137803044308542, 6: 0.6994752080732771}
#     15:37:50.069724 line       105 SOURCE IS UNAVAILABLE
#     Modified var:.. feature_idx = 7
#     15:37:51.921876 line       106 SOURCE IS UNAVAILABLE
#     15:37:53.760119 line       107 SOURCE IS UNAVAILABLE
#     15:37:55.647734 line       109 SOURCE IS UNAVAILABLE
#     Modified var:.. X_new = array([[ 0.77275753, -0.58037513,  0.36278033, ....       -0.06805734,  0.16387165]], dtype=float32)
#     15:37:57.557417 line       111 SOURCE IS UNAVAILABLE
#     15:37:59.410136 line       112 SOURCE IS UNAVAILABLE
#     Modified var:.. y_forecast = array([[ 7.8567713e-03, -7.4360982e-02, -2.23998... -2.1194809e-04, -8.6408683e-05]], dtype=float32)
#     15:38:01.231845 line       116 SOURCE IS UNAVAILABLE
#     15:38:03.077463 line       117 SOURCE IS UNAVAILABLE
#         Starting var:.. self = forwardfeatureadder(Afdict={'ctl': [array([[  0....224, 225,                                   226])
#         Starting var:.. yforecast = array([[ 7.8567713e-03, -7.4360982e-02, -2.23998... -2.1194809e-04, -8.6408683e-05]], dtype=float32)
#         15:38:04.952688 call        43 SOURCE IS UNAVAILABLE
#         15:38:05.433133 line        44 SOURCE IS UNAVAILABLE
#         15:38:05.977538 line        45 SOURCE IS UNAVAILABLE
#         15:38:06.521336 line        46 SOURCE IS UNAVAILABLE
#         15:38:07.039206 line        45 SOURCE IS UNAVAILABLE
#         15:38:07.498581 line        46 SOURCE IS UNAVAILABLE
#         15:38:08.008388 exception   46 SOURCE IS UNAVAILABLE
#         Exception:..... TypeError: 'int' object is not subscriptable
#         15:38:08.535946 line        48 SOURCE IS UNAVAILABLE
#         15:38:09.049205 line        49 SOURCE IS UNAVAILABLE
#         15:38:09.573471 line        50 SOURCE IS UNAVAILABLE
#         15:38:10.098720 line        49 SOURCE IS UNAVAILABLE
#         15:38:10.631811 line        50 SOURCE IS UNAVAILABLE
#         15:38:11.162925 line        49 SOURCE IS UNAVAILABLE
#         New var:....... temp1 = array([[-1.9476883e-04, -1.6931549e-04, -3.95609... -2.4237326e-05, -2.4298395e-05]], dtype=float32)
#         New var:....... temp2 = array([[-6.3743551e-05, -1.5022091e-04, -1.58488... -3.6870470e-06, -3.9023603e-06]], dtype=float32)
#         15:38:25.765617 line        51 SOURCE IS UNAVAILABLE
#         15:38:26.300328 return      51 SOURCE IS UNAVAILABLE
#         Return value:.. (array([[-1.9476883e-04, -1.6931549e-04, -3.9560...-3.6870470e-06, -3.9023603e-06]], dtype=float32))
#         Elapsed time: 00:00:21.899984
#     New var:....... teMP1 = array([[-1.9476883e-04, -1.6931549e-04, -3.95609... -2.4237326e-05, -2.4298395e-05]], dtype=float32)
#     New var:....... teMP2 = array([[-6.3743551e-05, -1.5022091e-04, -1.58488... -3.6870470e-06, -3.9023603e-06]], dtype=float32)
#     15:38:26.852717 line       118 SOURCE IS UNAVAILABLE
#     Modified var:.. teMP1s = array([[-1.9476883e-04, -1.6931549e-04, -3.95609... -4.2056563e-05, -4.5339562e-05]], dtype=float32)
#     Modified var:.. teMP2s = array([[-6.37435514e-05, -1.50220905e-04, -1.584...1.55045873e-05,  1.63567474e-05]], dtype=float32)
#     15:38:28.712596 line       119 SOURCE IS UNAVAILABLE
#     15:38:30.641783 line       120 SOURCE IS UNAVAILABLE
#     15:38:33.019466 line       122 SOURCE IS UNAVAILABLE
#     Modified var:.. scores = {0: 0.708665081653992, 1: 0.7268257973338567, 2:...42, 6: 0.6994752080732771, 7: 0.6929949640176385}
#     15:38:36.029222 line       105 SOURCE IS UNAVAILABLE
#     Modified var:.. feature_idx = 8
#     15:38:37.954801 line       106 SOURCE IS UNAVAILABLE
#     15:38:39.794662 line       107 SOURCE IS UNAVAILABLE
#     15:38:41.681795 line       109 SOURCE IS UNAVAILABLE
#     Modified var:.. X_new = array([[-0.51075447, -0.58037513,  0.36278033, ....       -0.06805734,  0.16387165]], dtype=float32)
#     15:38:43.539718 line       111 SOURCE IS UNAVAILABLE
#     15:38:45.425184 line       112 SOURCE IS UNAVAILABLE

# %%
holdmem
# Out:
# [217,
#  218,
#  219,
#  220,
#  221,
#  222,
#  223,
#  224,
#  225,
#  226,
#  25,
#  114,
#  3,
#  185,
#  178,
#  193,
#  28,
#  195,
#  47,
#  106]

# %%
listt = [int(obj) for obj in np.linspace(217,227-1,10)]
listt.append(176)

# %%
for index in listt:
    current_mask[index] = True

# %%
def comprehension_loop():
    return [task(image) for image in pics]

# %time test2 = comprehension_loop()
# Out:
# CPU times: user 1.46 s, sys: 4.18 ms, total: 1.47 s
# Wall time: 1.48 s

# %%
from joblib import Parallel, delayed
def joblib_loop():
    results = Parallel(n_jobs=2)(delayed(task)(i) for i in pics)
    return results

# %time 
test = joblib_loop()
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.58 µs

# %%
test[0]==test2[0]
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])
